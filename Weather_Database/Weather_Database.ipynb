# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Importing the citipy module.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the timelibrary and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | sofiyivka
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | lorengau
# Processing Record 7 of Set 1 | vitim
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 1 | srednekolymsk
# Processing Record 11 of Set 1 | naze
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | susanino
# Processing Record 15 of Set 1 | shihezi
# Processing Record 16 of Set 1 | panama city
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | concepcion
# Processing Record 20 of Set 1 | barbate
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 1 | dakar
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | havelock
# Processing Record 27 of Set 1 | beyneu
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | urumqi
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | esperance
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | lamlash
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | ixtapa
# Processing Record 37 of Set 1 | sovetskiy
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | grindavik
# Processing Record 40 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | arman
# Processing Record 43 of Set 1 | adrar
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | kahului
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | san patricio
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | charters towers
# Processing Record 1 of Set 2 | lasa
# Processing Record 2 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | yarada
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | vestmannaeyjar
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | meulaboh
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | flinders
# Processing Record 14 of Set 2 | envira
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | maridi
# Processing Record 17 of Set 2 | kirakira
# Processing Record 18 of Set 2 | san policarpo
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | nalut
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | muravlenko
# Processing Record 24 of Set 2 | vao
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | nador
# Processing Record 28 of Set 2 | bonthe
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | sosua
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | maragheh
# Processing Record 36 of Set 2 | caravelas
# Processing Record 37 of Set 2 | paraiso
# Processing Record 38 of Set 2 | batemans bay
# Processing Record 39 of Set 2 | san cristobal
# Processing Record 40 of Set 2 | bairiki
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | beipiao
# Processing Record 43 of Set 2 | touros
# Processing Record 44 of Set 2 | bardiyah
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | sobolevo
# Processing Record 47 of Set 2 | san pedro del pinatar
# Processing Record 48 of Set 2 | katherine
# Processing Record 49 of Set 2 | nikolskoye
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 3 | oloron-sainte-marie
# Processing Record 3 of Set 3 | kamenka
# Processing Record 4 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 3 | freeport
# Processing Record 6 of Set 3 | sept-iles
# Processing Record 7 of Set 3 | salalah
# Processing Record 8 of Set 3 | aksarka
# Processing Record 9 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 3 | brokopondo
# Processing Record 11 of Set 3 | sumbe
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | zyryanovsk
# Processing Record 15 of Set 3 | graham
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | korop
# Processing Record 19 of Set 3 | pangnirtung
# Processing Record 20 of Set 3 | jiangyou
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | cap-chat
# Processing Record 24 of Set 3 | ibra
# Processing Record 25 of Set 3 | elban
# Processing Record 26 of Set 3 | veinticinco de mayo
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | khudumelapye
# Processing Record 29 of Set 3 | kushiro
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | vostok
# Processing Record 32 of Set 3 | stornoway
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | cidreira
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | jaru
# Processing Record 37 of Set 3 | gondanglegi
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 3 | shibukawa
# Processing Record 41 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 3 | mancio lima
# Processing Record 44 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 3 | emerald
# Processing Record 46 of Set 3 | niquero
# Processing Record 47 of Set 3 | nanortalik
# Processing Record 48 of Set 3 | grand gaube
# Processing Record 49 of Set 3 | prince rupert
# Processing Record 50 of Set 3 | cordoba
# Processing Record 1 of Set 4 | vaini
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | nueva concepcion
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | westlock
# Processing Record 6 of Set 4 | semey
# Processing Record 7 of Set 4 | zhigansk
# Processing Record 8 of Set 4 | katsuura
# Processing Record 9 of Set 4 | kinston
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | erzin
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | geraldton
# Processing Record 14 of Set 4 | avarua
# Processing Record 15 of Set 4 | tadine
# Processing Record 16 of Set 4 | zhuanghe
# Processing Record 17 of Set 4 | aleysk
# Processing Record 18 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 4 | burica
# City not found. Skipping...
# Processing Record 20 of Set 4 | yaan
# Processing Record 21 of Set 4 | ostrovnoy
# Processing Record 22 of Set 4 | ploemeur
# Processing Record 23 of Set 4 | markapur
# Processing Record 24 of Set 4 | kaeo
# Processing Record 25 of Set 4 | kamaishi
# Processing Record 26 of Set 4 | tasiilaq
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | rundu
# Processing Record 29 of Set 4 | khairagarh
# Processing Record 30 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 31 of Set 4 | sechura
# Processing Record 32 of Set 4 | constitucion
# Processing Record 33 of Set 4 | plaster rock
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | henties bay
# Processing Record 36 of Set 4 | hofn
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | tuatapere
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | sao filipe
# Processing Record 42 of Set 4 | tokur
# Processing Record 43 of Set 4 | carlyle
# Processing Record 44 of Set 4 | ratnagiri
# Processing Record 45 of Set 4 | mandalgovi
# Processing Record 46 of Set 4 | mayo
# Processing Record 47 of Set 4 | mbandaka
# Processing Record 48 of Set 4 | veles
# Processing Record 49 of Set 4 | carahue
# Processing Record 50 of Set 4 | yuksekova
# Processing Record 1 of Set 5 | mar del plata
# Processing Record 2 of Set 5 | cherskiy
# Processing Record 3 of Set 5 | comodoro rivadavia
# Processing Record 4 of Set 5 | bubaque
# Processing Record 5 of Set 5 | namibe
# Processing Record 6 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 5 | saint george
# Processing Record 8 of Set 5 | tucuma
# Processing Record 9 of Set 5 | tautira
# Processing Record 10 of Set 5 | kalemie
# Processing Record 11 of Set 5 | hami
# Processing Record 12 of Set 5 | pochutla
# Processing Record 13 of Set 5 | yanam
# Processing Record 14 of Set 5 | munster
# Processing Record 15 of Set 5 | novyy nekouz
# Processing Record 16 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 5 | tilichiki
# Processing Record 18 of Set 5 | asau
# Processing Record 19 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 5 | lodja
# Processing Record 21 of Set 5 | todos santos
# Processing Record 22 of Set 5 | byron bay
# Processing Record 23 of Set 5 | saldanha
# Processing Record 24 of Set 5 | ust-ishim
# Processing Record 25 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 26 of Set 5 | mahajanga
# Processing Record 27 of Set 5 | rocha
# Processing Record 28 of Set 5 | cabedelo
# Processing Record 29 of Set 5 | nedjo
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | wicklow
# Processing Record 33 of Set 5 | lagoa
# Processing Record 34 of Set 5 | talnakh
# Processing Record 35 of Set 5 | sri aman
# Processing Record 36 of Set 5 | imisli
# City not found. Skipping...
# Processing Record 37 of Set 5 | port augusta
# Processing Record 38 of Set 5 | skala fourkas
# Processing Record 39 of Set 5 | banda aceh
# Processing Record 40 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 5 | parabel
# Processing Record 42 of Set 5 | coihaique
# Processing Record 43 of Set 5 | okato
# Processing Record 44 of Set 5 | zabaykalsk
# Processing Record 45 of Set 5 | abhayapuri
# Processing Record 46 of Set 5 | muli
# Processing Record 47 of Set 5 | ayan
# Processing Record 48 of Set 5 | mporokoso
# Processing Record 49 of Set 5 | genhe
# Processing Record 50 of Set 5 | puerto del rosario
# Processing Record 1 of Set 6 | marawi
# Processing Record 2 of Set 6 | verkhnyaya inta
# Processing Record 3 of Set 6 | usinsk
# Processing Record 4 of Set 6 | channel-port aux basques
# Processing Record 5 of Set 6 | ban dung
# Processing Record 6 of Set 6 | ancud
# Processing Record 7 of Set 6 | vila velha
# Processing Record 8 of Set 6 | chara
# Processing Record 9 of Set 6 | mangrol
# Processing Record 10 of Set 6 | yar-sale
# Processing Record 11 of Set 6 | shahrud
# Processing Record 12 of Set 6 | bengkulu
# Processing Record 13 of Set 6 | faya
# Processing Record 14 of Set 6 | onega
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 6 | moussoro
# Processing Record 18 of Set 6 | maholi
# Processing Record 19 of Set 6 | esna
# Processing Record 20 of Set 6 | shingu
# Processing Record 21 of Set 6 | rio gallegos
# Processing Record 22 of Set 6 | margate
# Processing Record 23 of Set 6 | popondetta
# Processing Record 24 of Set 6 | perry
# Processing Record 25 of Set 6 | abu kamal
# Processing Record 26 of Set 6 | xingyi
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | saint-pierre
# Processing Record 29 of Set 6 | chumikan
# Processing Record 30 of Set 6 | mandali
# Processing Record 31 of Set 6 | wichita falls
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | anshun
# Processing Record 34 of Set 6 | verkhniy baskunchak
# Processing Record 35 of Set 6 | dhidhdhoo
# Processing Record 36 of Set 6 | ayutla
# Processing Record 37 of Set 6 | hokitika
# Processing Record 38 of Set 6 | kodiak
# Processing Record 39 of Set 6 | castro
# Processing Record 40 of Set 6 | jacala
# Processing Record 41 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 42 of Set 6 | uberlandia
# Processing Record 43 of Set 6 | staryy nadym
# Processing Record 44 of Set 6 | daru
# Processing Record 45 of Set 6 | guerrero negro
# Processing Record 46 of Set 6 | baruun-urt
# Processing Record 47 of Set 6 | mtwara
# Processing Record 48 of Set 6 | korla
# Processing Record 49 of Set 6 | omboue
# Processing Record 50 of Set 6 | kailua
# Processing Record 1 of Set 7 | den helder
# Processing Record 2 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 7 | anuradhapura
# Processing Record 4 of Set 7 | beroroha
# Processing Record 5 of Set 7 | kaitangata
# Processing Record 6 of Set 7 | tamandare
# Processing Record 7 of Set 7 | acapulco
# Processing Record 8 of Set 7 | adoni
# Processing Record 9 of Set 7 | cayenne
# Processing Record 10 of Set 7 | husavik
# Processing Record 11 of Set 7 | torbay
# Processing Record 12 of Set 7 | kolokani
# Processing Record 13 of Set 7 | cockburn town
# Processing Record 14 of Set 7 | port blair
# Processing Record 15 of Set 7 | najran
# Processing Record 16 of Set 7 | tezu
# Processing Record 17 of Set 7 | baherden
# Processing Record 18 of Set 7 | lebu
# Processing Record 19 of Set 7 | merauke
# Processing Record 20 of Set 7 | mutis
# Processing Record 21 of Set 7 | hirara
# Processing Record 22 of Set 7 | kalianget
# Processing Record 23 of Set 7 | beringovskiy
# Processing Record 24 of Set 7 | half moon bay
# Processing Record 25 of Set 7 | kathu
# Processing Record 26 of Set 7 | show low
# Processing Record 27 of Set 7 | itarema
# Processing Record 28 of Set 7 | hailar
# Processing Record 29 of Set 7 | kargasok
# Processing Record 30 of Set 7 | bhadrachalam
# Processing Record 31 of Set 7 | fare
# Processing Record 32 of Set 7 | saint-francois
# Processing Record 33 of Set 7 | camacha
# Processing Record 34 of Set 7 | lazaro cardenas
# Processing Record 35 of Set 7 | nevelsk
# Processing Record 36 of Set 7 | pyinmana
# Processing Record 37 of Set 7 | kenora
# Processing Record 38 of Set 7 | voznesenye
# Processing Record 39 of Set 7 | sinjar
# Processing Record 40 of Set 7 | manavgat
# Processing Record 41 of Set 7 | rabo de peixe
# Processing Record 42 of Set 7 | pyaozerskiy
# Processing Record 43 of Set 7 | lavrentiya
# Processing Record 44 of Set 7 | namie
# Processing Record 45 of Set 7 | maragogi
# Processing Record 46 of Set 7 | manicore
# Processing Record 47 of Set 7 | mezhdurechenskiy
# Processing Record 48 of Set 7 | vardo
# Processing Record 49 of Set 7 | portalegre
# Processing Record 50 of Set 7 | provideniya
# Processing Record 1 of Set 8 | oga
# Processing Record 2 of Set 8 | kushikino
# Processing Record 3 of Set 8 | matara
# Processing Record 4 of Set 8 | laguna
# Processing Record 5 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 8 | codrington
# Processing Record 7 of Set 8 | araguaina
# Processing Record 8 of Set 8 | redlands
# Processing Record 9 of Set 8 | port hardy
# Processing Record 10 of Set 8 | skeldon
# Processing Record 11 of Set 8 | tanabe
# Processing Record 12 of Set 8 | lompoc
# Processing Record 13 of Set 8 | rosetta
# Processing Record 14 of Set 8 | novoorsk
# Processing Record 15 of Set 8 | tucuman
# Processing Record 16 of Set 8 | belomorsk
# Processing Record 17 of Set 8 | kampene
# Processing Record 18 of Set 8 | gander
# Processing Record 19 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 20 of Set 8 | bandarbeyla
# Processing Record 21 of Set 8 | madison
# Processing Record 22 of Set 8 | kieta
# Processing Record 23 of Set 8 | port-cartier
# Processing Record 24 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 25 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 26 of Set 8 | zyryanka
# Processing Record 27 of Set 8 | moose factory
# Processing Record 28 of Set 8 | yerbogachen
# Processing Record 29 of Set 8 | gaziantep
# Processing Record 30 of Set 8 | xichang
# Processing Record 31 of Set 8 | bahia blanca
# Processing Record 32 of Set 8 | upata
# Processing Record 33 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 8 | shache
# Processing Record 35 of Set 8 | richards bay
# Processing Record 36 of Set 8 | umm kaddadah
# Processing Record 37 of Set 8 | boddam
# Processing Record 38 of Set 8 | jumla
# Processing Record 39 of Set 8 | trairi
# Processing Record 40 of Set 8 | barahona
# Processing Record 41 of Set 8 | ozinki
# Processing Record 42 of Set 8 | castelo do piaui
# Processing Record 43 of Set 8 | manaure
# Processing Record 44 of Set 8 | muros
# Processing Record 45 of Set 8 | hamilton
# Processing Record 46 of Set 8 | port hedland
# Processing Record 47 of Set 8 | aswan
# Processing Record 48 of Set 8 | tucurui
# Processing Record 49 of Set 8 | yenagoa
# Processing Record 50 of Set 8 | boundiali
# Processing Record 1 of Set 9 | carutapera
# Processing Record 2 of Set 9 | king city
# Processing Record 3 of Set 9 | suwannaphum
# Processing Record 4 of Set 9 | olafsvik
# Processing Record 5 of Set 9 | laukaa
# Processing Record 6 of Set 9 | tsabong
# Processing Record 7 of Set 9 | say
# Processing Record 8 of Set 9 | sayansk
# Processing Record 9 of Set 9 | clyde river
# Processing Record 10 of Set 9 | karratha
# Processing Record 11 of Set 9 | dieppe
# Processing Record 12 of Set 9 | nome
# Processing Record 13 of Set 9 | kichera
# Processing Record 14 of Set 9 | skibbereen
# Processing Record 15 of Set 9 | sobinka
# Processing Record 16 of Set 9 | ituiutaba
# Processing Record 17 of Set 9 | gravdal
# Processing Record 18 of Set 9 | peterhead
# Processing Record 19 of Set 9 | saint-philippe
# Processing Record 20 of Set 9 | bahawalpur
# Processing Record 21 of Set 9 | banepa
# Processing Record 22 of Set 9 | champerico
# Processing Record 23 of Set 9 | kidal
# Processing Record 24 of Set 9 | kinanah
# City not found. Skipping...
# Processing Record 25 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 9 | chany
# Processing Record 27 of Set 9 | isangel
# Processing Record 28 of Set 9 | araguacu
# Processing Record 29 of Set 9 | cabra
# Processing Record 30 of Set 9 | samarai
# Processing Record 31 of Set 9 | tahe
# Processing Record 32 of Set 9 | santa cruz
# Processing Record 33 of Set 9 | nanakuli
# Processing Record 34 of Set 9 | singapore
# Processing Record 35 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 9 | marquard
# Processing Record 37 of Set 9 | norman wells
# Processing Record 38 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 9 | ponta do sol
# Processing Record 40 of Set 9 | bilibino
# Processing Record 41 of Set 9 | choachi
# Processing Record 42 of Set 9 | ahuimanu
# Processing Record 43 of Set 9 | yangjiang
# Processing Record 44 of Set 9 | naryan-mar
# Processing Record 45 of Set 9 | virarajendrapet
# Processing Record 46 of Set 9 | mantua
# Processing Record 47 of Set 9 | kamina
# Processing Record 48 of Set 9 | dawei
# Processing Record 49 of Set 9 | anicuns
# Processing Record 50 of Set 9 | palmer
# Processing Record 1 of Set 10 | sisimiut
# Processing Record 2 of Set 10 | utica
# Processing Record 3 of Set 10 | kautokeino
# Processing Record 4 of Set 10 | pekan
# Processing Record 5 of Set 10 | hutchinson
# Processing Record 6 of Set 10 | pimenta bueno
# Processing Record 7 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 8 of Set 10 | zhuji
# Processing Record 9 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 10 | komsomolskiy
# Processing Record 11 of Set 10 | anadyr
# Processing Record 12 of Set 10 | warkworth
# Processing Record 13 of Set 10 | gizo
# Processing Record 14 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 10 | mizan teferi
# Processing Record 16 of Set 10 | araouane
# Processing Record 17 of Set 10 | grand-santi
# Processing Record 18 of Set 10 | port-gentil
# Processing Record 19 of Set 10 | skjervoy
# Processing Record 20 of Set 10 | deputatskiy
# Processing Record 21 of Set 10 | ambulu
# Processing Record 22 of Set 10 | kiama
# Processing Record 23 of Set 10 | brigantine
# Processing Record 24 of Set 10 | kiunga
# Processing Record 25 of Set 10 | makakilo city
# Processing Record 26 of Set 10 | wawa
# Processing Record 27 of Set 10 | lewistown
# Processing Record 28 of Set 10 | benito juarez
# Processing Record 29 of Set 10 | abja-paluoja
# Processing Record 30 of Set 10 | hammerfest
# Processing Record 31 of Set 10 | poum
# Processing Record 32 of Set 10 | viedma
# Processing Record 33 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 10 | mount isa
# Processing Record 35 of Set 10 | teguise
# Processing Record 36 of Set 10 | huarmey
# Processing Record 37 of Set 10 | nago
# Processing Record 38 of Set 10 | brae
# Processing Record 39 of Set 10 | opobo
# City not found. Skipping...
# Processing Record 40 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 10 | peniche
# Processing Record 42 of Set 10 | khandyga
# Processing Record 43 of Set 10 | yumen
# Processing Record 44 of Set 10 | lagos
# Processing Record 45 of Set 10 | aksu
# Processing Record 46 of Set 10 | medvedevo
# Processing Record 47 of Set 10 | halifax
# Processing Record 48 of Set 10 | juneau
# Processing Record 49 of Set 10 | hue
# Processing Record 50 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 11 | seoul
# Processing Record 2 of Set 11 | batagay
# Processing Record 3 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 4 of Set 11 | igarka
# Processing Record 5 of Set 11 | balakhta
# Processing Record 6 of Set 11 | raudeberg
# Processing Record 7 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 11 | ovsyanka
# Processing Record 9 of Set 11 | abu samrah
# Processing Record 10 of Set 11 | arcani
# Processing Record 11 of Set 11 | ler
# Processing Record 12 of Set 11 | los llanos de aridane
# Processing Record 13 of Set 11 | sarangani
# Processing Record 14 of Set 11 | chapais
# Processing Record 15 of Set 11 | egvekinot
# Processing Record 16 of Set 11 | acajutla
# Processing Record 17 of Set 11 | presidencia roque saenz pena
# Processing Record 18 of Set 11 | matay
# Processing Record 19 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 11 | san jose
# Processing Record 21 of Set 11 | rudnogorsk
# Processing Record 22 of Set 11 | mutare
# Processing Record 23 of Set 11 | saraland
# Processing Record 24 of Set 11 | the pas
# Processing Record 25 of Set 11 | winfield
# Processing Record 26 of Set 11 | togur
# Processing Record 27 of Set 11 | linxi
# Processing Record 28 of Set 11 | maumere
# Processing Record 29 of Set 11 | narsaq
# Processing Record 30 of Set 11 | makarov
# Processing Record 31 of Set 11 | padang
# Processing Record 32 of Set 11 | roros
# Processing Record 33 of Set 11 | talcahuano
# Processing Record 34 of Set 11 | moindou
# Processing Record 35 of Set 11 | tual
# Processing Record 36 of Set 11 | iisalmi
# Processing Record 37 of Set 11 | alice springs
# Processing Record 38 of Set 11 | sehithwa
# Processing Record 39 of Set 11 | zhuhai
# Processing Record 40 of Set 11 | corner brook
# Processing Record 41 of Set 11 | rujewa
# Processing Record 42 of Set 11 | qeshm
# Processing Record 43 of Set 11 | sozimskiy
# Processing Record 44 of Set 11 | dukat
# Processing Record 45 of Set 11 | aktau
# Processing Record 46 of Set 11 | amapala
# Processing Record 47 of Set 11 | vila
# Processing Record 48 of Set 11 | vanavara
# Processing Record 49 of Set 11 | voyvozh
# Processing Record 50 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 1 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 12 | mogadishu
# Processing Record 4 of Set 12 | moyale
# Processing Record 5 of Set 12 | tabou
# Processing Record 6 of Set 12 | qaqortoq
# Processing Record 7 of Set 12 | riyadh
# Processing Record 8 of Set 12 | dunedin
# Processing Record 9 of Set 12 | san vicente
# Processing Record 10 of Set 12 | cholet
# Processing Record 11 of Set 12 | tamiahua
# Processing Record 12 of Set 12 | havre-saint-pierre
# Processing Record 13 of Set 12 | kotovo
# Processing Record 14 of Set 12 | khargupur
# Processing Record 15 of Set 12 | zharkent
# Processing Record 16 of Set 12 | danville
# Processing Record 17 of Set 12 | leshukonskoye
# Processing Record 18 of Set 12 | hovd
# Processing Record 19 of Set 12 | elizabeth city
# Processing Record 20 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 21 of Set 12 | haines junction
# Processing Record 22 of Set 12 | poronaysk
# Processing Record 23 of Set 12 | calabozo
# Processing Record 24 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 25 of Set 12 | kapiri mposhi
# Processing Record 26 of Set 12 | ganzhou
# Processing Record 27 of Set 12 | sur
# Processing Record 28 of Set 12 | nouadhibou
# Processing Record 29 of Set 12 | bagotville
# Processing Record 30 of Set 12 | makhachkala
# Processing Record 31 of Set 12 | soria
# Processing Record 32 of Set 12 | portland
# Processing Record 33 of Set 12 | lamu
# Processing Record 34 of Set 12 | zhanakorgan
# Processing Record 35 of Set 12 | soe
# Processing Record 36 of Set 12 | coahuayana
# Processing Record 37 of Set 12 | dawlatabad
# Processing Record 38 of Set 12 | laibin
# Processing Record 39 of Set 12 | rondonopolis
# Processing Record 40 of Set 12 | fallon
# Processing Record 41 of Set 12 | balkhash
# Processing Record 42 of Set 12 | henderson
# Processing Record 43 of Set 12 | plast
# Processing Record 44 of Set 12 | farso
# Processing Record 45 of Set 12 | ipixuna
# Processing Record 46 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 12 | montepuez
# Processing Record 48 of Set 12 | nouakchott
# Processing Record 49 of Set 12 | pontianak
# Processing Record 50 of Set 12 | changji
# Processing Record 1 of Set 13 | namatanai
# Processing Record 2 of Set 13 | lufilufi
# Processing Record 3 of Set 13 | mobo
# Processing Record 4 of Set 13 | isilkul
# Processing Record 5 of Set 13 | kemptville
# Processing Record 6 of Set 13 | saint-augustin
# Processing Record 7 of Set 13 | taoudenni
# Processing Record 8 of Set 13 | atar
# Processing Record 9 of Set 13 | kincardine
# Processing Record 10 of Set 13 | chamonix-mont-blanc
# Processing Record 11 of Set 13 | buga
# Processing Record 12 of Set 13 | aleksandrov gay
# Processing Record 13 of Set 13 | natal
# Processing Record 14 of Set 13 | raga
# Processing Record 15 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 13 | redcar
# Processing Record 17 of Set 13 | san juan evangelista
# Processing Record 18 of Set 13 | tura
# Processing Record 19 of Set 13 | boa vista
# Processing Record 20 of Set 13 | aljezur
# Processing Record 21 of Set 13 | ambilobe
# Processing Record 22 of Set 13 | takoradi
# Processing Record 23 of Set 13 | yen bai
# Processing Record 24 of Set 13 | vila franca do campo
# Processing Record 25 of Set 13 | valparaiso
# Processing Record 26 of Set 13 | talas
# Processing Record 27 of Set 13 | klaksvik
# Processing Record 28 of Set 13 | chengmai
# City not found. Skipping...
# Processing Record 29 of Set 13 | palmares do sul
# Processing Record 30 of Set 13 | safford
# Processing Record 31 of Set 13 | maceio
# Processing Record 32 of Set 13 | sahuaripa
# Processing Record 33 of Set 13 | gat
# Processing Record 34 of Set 13 | wichita
# Processing Record 35 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 13 | ust-omchug
# Processing Record 38 of Set 13 | nortelandia
# Processing Record 39 of Set 13 | urengoy
# Processing Record 40 of Set 13 | bambanglipuro
# Processing Record 41 of Set 13 | tarbagatay
# Processing Record 42 of Set 13 | broome
# Processing Record 43 of Set 13 | sistranda
# Processing Record 44 of Set 13 | gamba
# Processing Record 45 of Set 13 | jurado
# Processing Record 46 of Set 13 | vondrozo
# Processing Record 47 of Set 13 | kibala
# Processing Record 48 of Set 13 | lovozero
# Processing Record 49 of Set 13 | berlevag
# Processing Record 50 of Set 13 | takestan
# Processing Record 1 of Set 14 | sebeta
# Processing Record 2 of Set 14 | chuguyevka
# Processing Record 3 of Set 14 | pedernales
# Processing Record 4 of Set 14 | ugoofaaru
# Processing Record 5 of Set 14 | pingchen
# City not found. Skipping...
# Processing Record 6 of Set 14 | matola
# Processing Record 7 of Set 14 | dudinka
# Processing Record 8 of Set 14 | turbat
# Processing Record 9 of Set 14 | taltal
# Processing Record 10 of Set 14 | ust-ilimsk
# Processing Record 11 of Set 14 | fairbanks
# Processing Record 12 of Set 14 | uige
# Processing Record 13 of Set 14 | ormond beach
# Processing Record 14 of Set 14 | jinchang
# Processing Record 15 of Set 14 | kindu
# Processing Record 16 of Set 14 | mama
# Processing Record 17 of Set 14 | lukovetskiy
# Processing Record 18 of Set 14 | ambatofinandrahana
# Processing Record 19 of Set 14 | gilgit
# Processing Record 20 of Set 14 | ginda
# Processing Record 21 of Set 14 | hualmay
# Processing Record 22 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 14 | mareeba
# Processing Record 25 of Set 14 | barra da estiva
# Processing Record 26 of Set 14 | kurush
# Processing Record 27 of Set 14 | la serena
# Processing Record 28 of Set 14 | celestun
# Processing Record 29 of Set 14 | hasaki
# Processing Record 30 of Set 14 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 31 of Set 14 | siuna
# Processing Record 32 of Set 14 | singaraja
# Processing Record 33 of Set 14 | macas
# Processing Record 34 of Set 14 | vanimo
# Processing Record 35 of Set 14 | arsk
# Processing Record 36 of Set 14 | thinadhoo
# Processing Record 37 of Set 14 | sao lourenco do sul
# Processing Record 38 of Set 14 | senno
# Processing Record 39 of Set 14 | karasjok
# Processing Record 40 of Set 14 | mahibadhoo
# Processing Record 41 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 14 | sambava
# Processing Record 43 of Set 14 | carai
# Processing Record 44 of Set 14 | mackay
# Processing Record 45 of Set 14 | ubinskoye
# Processing Record 46 of Set 14 | georgiyevka
# Processing Record 47 of Set 14 | caliling
# Processing Record 48 of Set 14 | tevriz
# Processing Record 49 of Set 14 | ijui
# Processing Record 50 of Set 14 | doda
# Processing Record 1 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 2 of Set 15 | yuci
# Processing Record 3 of Set 15 | male
# Processing Record 4 of Set 15 | paamiut
# Processing Record 5 of Set 15 | zhangye
# Processing Record 6 of Set 15 | oromocto
# Processing Record 7 of Set 15 | villarrobledo
# Processing Record 8 of Set 15 | kifri
# Processing Record 9 of Set 15 | olinda
# Processing Record 10 of Set 15 | duku
# Processing Record 11 of Set 15 | praia
# Processing Record 12 of Set 15 | khanpur
# Processing Record 13 of Set 15 | berlin
# Processing Record 14 of Set 15 | nyurba
# Processing Record 15 of Set 15 | nizhniy baskunchak
# Processing Record 16 of Set 15 | kalininsk
# Processing Record 17 of Set 15 | shakiso
# Processing Record 18 of Set 15 | canutama
# Processing Record 19 of Set 15 | acarau
# Processing Record 20 of Set 15 | cuamba
# Processing Record 21 of Set 15 | sao miguel do araguaia
# Processing Record 22 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 15 | irtyshskiy
# Processing Record 24 of Set 15 | quelimane
# Processing Record 25 of Set 15 | ponta delgada
# Processing Record 26 of Set 15 | mehamn
# Processing Record 27 of Set 15 | aklavik
# Processing Record 28 of Set 15 | gornopravdinsk
# Processing Record 29 of Set 15 | bartica
# Processing Record 30 of Set 15 | mayumba
# Processing Record 31 of Set 15 | kudahuvadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tallying number of cities in the city_data array of dictionaries.
len(city_data)
# Out:
# 666

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hilo  19.7297 -155.0900     67.73        84         100
# 1   Punta Arenas -53.1500  -70.9167     57.31        47          40
# 2      Sofiyivka  48.0493   33.8746     35.98        71         100
# 3        Qaanaaq  77.4840  -69.3632    -21.21        48           0
# 4     Georgetown   5.4112  100.3354     83.89        74          20
# 5       Lorengau  -2.0226  147.2712     80.80        75          92
# 6          Vitim  59.4511  112.5578    -22.92       100          23
# 7    Port Alfred -33.5906   26.8910     80.51        78           9
# 8  Srednekolymsk  67.4500  153.6833    -33.20        98          58
# 9           Naze  28.3667  129.4833     62.06        89         100
#
#    Wind Speed Country Current Description                 Date
# 0        1.01      US     overcast clouds  2022-02-12 15:11:19
# 1       36.82      CL    scattered clouds  2022-02-12 15:06:58
# 2       18.75      UA     overcast clouds  2022-02-12 15:11:19
# 3        8.55      GL           clear sky  2022-02-12 15:11:19
# 4        1.99      MY          few clouds  2022-02-12 15:11:11
# 5        3.33      PG     overcast clouds  2022-02-12 15:11:20
# 6        1.12      RU          few clouds  2022-02-12 15:11:20
# 7       18.75      ZA           clear sky  2022-02-12 15:11:20
# 8        7.16      RU       broken clouds  2022-02-12 15:11:21
# 9       14.43      JP     overcast clouds  2022-02-12 15:11:21

# %%
# Reordering the columns.
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0           Hilo      US  2022-02-12 15:11:19  19.7297 -155.0900     67.73
# 1   Punta Arenas      CL  2022-02-12 15:06:58 -53.1500  -70.9167     57.31
# 2      Sofiyivka      UA  2022-02-12 15:11:19  48.0493   33.8746     35.98
# 3        Qaanaaq      GL  2022-02-12 15:11:19  77.4840  -69.3632    -21.21
# 4     Georgetown      MY  2022-02-12 15:11:11   5.4112  100.3354     83.89
# 5       Lorengau      PG  2022-02-12 15:11:20  -2.0226  147.2712     80.80
# 6          Vitim      RU  2022-02-12 15:11:20  59.4511  112.5578    -22.92
# 7    Port Alfred      ZA  2022-02-12 15:11:20 -33.5906   26.8910     80.51
# 8  Srednekolymsk      RU  2022-02-12 15:11:21  67.4500  153.6833    -33.20
# 9           Naze      JP  2022-02-12 15:11:21  28.3667  129.4833     62.06
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        84         100        1.01     overcast clouds
# 1        47          40       36.82    scattered clouds
# 2        71         100       18.75     overcast clouds
# 3        48           0        8.55           clear sky
# 4        74          20        1.99          few clouds
# 5        75          92        3.33     overcast clouds
# 6       100          23        1.12          few clouds
# 7        78           9       18.75           clear sky
# 8        98          58        7.16       broken clouds
# 9        89         100       14.43     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
